# %%
import pandas as pd

# %%
vine_df = pd.read_csv("./Data/vine_table.csv")

vine_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R3P2HIOQCIN5ZU            1              0            0    N
# 1        R12VVR0WH5Q24V            5              0            0    N
# 2         RNCCKB6TV5EEF            4              0            0    N
# 3        R2NZXYIVCGB13W            5              0            6    N
# 4        R2EQ1TG9IT3OEQ            3              0            0    N
# ...                 ...          ...            ...          ...  ...
# 4366911  R2C0JM229QZS0R            4              1            6    N
# 4366912  R3CBWUG8E05BFU            1              5            5    N
# 4366913   RN7TB51V24XHT            4              7            7    N
# 4366914  R22CRGBKA02SPB            5              3            3    N
# 4366915  R1NR3UYEZ0M8KQ            1             12           13    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# 3                       Y
# 4                       Y
# ...                   ...
# 4366911                 N
# 4366912                 N
# 4366913                 N
# 4366914                 N
# 4366915                 N
#
# [4366916 rows x 6 columns]

# %%
vine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4366916 entries, 0 to 4366915
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   review_id          object
#  1   star_rating        int64
#  2   helpful_votes      int64
#  3   total_votes        int64
#  4   vine               object
#  5   verified_purchase  object
# dtypes: int64(3), object(3)
# memory usage: 199.9+ MB

# %%
vine_df_20 = vine_df.loc[vine_df["total_votes"] >= 20]
vine_df_20
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 218      R37F42INKX7L9K            5             45           49    N
# 557      R2EHKYNEP8WVSR            5             25           25    N
# 560       RXOS7BHID0UHL            5             16           27    N
# 909      R33HHGFPB403GM            5             19           21    N
# 1232      RY9O9XNLP464N            2             19           22    N
# ...                 ...          ...            ...          ...  ...
# 4366771  R1UYT6MT2IOAJN            5             23           24    N
# 4366804   R8FUPKU9V9O8C            5              3           28    N
# 4366844  R3QRYRJWX0N6H3            4             29           33    N
# 4366886   R20WGBU79NREU            5             14           20    N
# 4366893  R2JC45DHFX613N            5              6           24    N
#
#         verified_purchase
# 218                     Y
# 557                     Y
# 560                     N
# 909                     Y
# 1232                    Y
# ...                   ...
# 4366771                 N
# 4366804                 N
# 4366844                 N
# 4366886                 N
# 4366893                 N
#
# [27884 rows x 6 columns]

# %%
vine_df_50 = vine_df_20.loc[(vine_df_20["helpful_votes"] / vine_df_20["total_votes"]) >= 0.50]
vine_df_50
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 218      R37F42INKX7L9K            5             45           49    N
# 557      R2EHKYNEP8WVSR            5             25           25    N
# 560       RXOS7BHID0UHL            5             16           27    N
# 909      R33HHGFPB403GM            5             19           21    N
# 1232      RY9O9XNLP464N            2             19           22    N
# ...                 ...          ...            ...          ...  ...
# 4366751  R1FALBZOUYCZTD            5             29           31    N
# 4366765   R7M3UQX8B04NM            5             20           21    N
# 4366771  R1UYT6MT2IOAJN            5             23           24    N
# 4366844  R3QRYRJWX0N6H3            4             29           33    N
# 4366886   R20WGBU79NREU            5             14           20    N
#
#         verified_purchase
# 218                     Y
# 557                     Y
# 560                     N
# 909                     Y
# 1232                    Y
# ...                   ...
# 4366751                 N
# 4366765                 N
# 4366771                 N
# 4366844                 N
# 4366886                 N
#
# [27009 rows x 6 columns]

# %%
paid_reviews_df = vine_df_50.loc[vine_df_50["vine"] == 'Y']
paid_reviews_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 270349   R2N45ZKRRZS856            5             21           22    Y
# 306676    R5OMLMK13A8NS            5             34           38    Y
# 1050160  R2MPEQ4SPTEQNS            4            180          184    Y
# 1224726   RIR0D3KJ0CQ31            4             21           21    Y
# 1231743  R1SPWJDHUWWC5E            5             88           98    Y
# 1243026  R1X6M5XA3FT98W            5             24           26    Y
# 1268364  R37VCW6HA0Z72T            5             27           28    Y
# 1290559  R2XRYNV2SY3ZKL            5             53           56    Y
# 1312559  R1Y93KWKAX1P5N            2             26           31    Y
# 1312914  R2QVTDYYLTP8SL            5             21           24    Y
# 1315594  R3KOK2SH39BZU1            3             94           96    Y
# 1319788  R2VOM73EHLPXJW            4             35           38    Y
# 1327911  R3SEZS7BZEC69Y            5             16           20    Y
# 1330791  R1MJ5J272V19O6            4             49           51    Y
# 1348086  R3A7BQX1JDKOM5            4             20           20    Y
# 1509983  R1307JMPUEQXOW            5             31           35    Y
# 1622137   RXV0SDXE5B15T            2             39           42    Y
# 2373630   RBMDYE7LUH9FI            5             26           32    Y
# 2439075  R1N4W961QV59BV            5             25           34    Y
# 2440481  R11XKHFS4KQS3Z            4            205          211    Y
# 2462716  R2AT1A0VUSY955            5             22           24    Y
# 3791315   RMFBF4KEBW9RK            5             37           43    Y
#
#         verified_purchase
# 270349                  N
# 306676                  N
# 1050160                 N
# 1224726                 N
# 1231743                 N
# 1243026                 N
# 1268364                 N
# 1290559                 N
# 1312559                 N
# 1312914                 N
# 1315594                 N
# 1319788                 N
# 1327911                 N
# 1330791                 N
# 1348086                 N
# 1509983                 N
# 1622137                 N
# 2373630                 N
# 2439075                 N
# 2440481                 N
# 2462716                 N
# 3791315                 N

# %%
unpaid_reviews_df = vine_df_50.loc[vine_df_50["vine"] == 'N']
unpaid_reviews_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 218      R37F42INKX7L9K            5             45           49    N
# 557      R2EHKYNEP8WVSR            5             25           25    N
# 560       RXOS7BHID0UHL            5             16           27    N
# 909      R33HHGFPB403GM            5             19           21    N
# 1232      RY9O9XNLP464N            2             19           22    N
# ...                 ...          ...            ...          ...  ...
# 4366751  R1FALBZOUYCZTD            5             29           31    N
# 4366765   R7M3UQX8B04NM            5             20           21    N
# 4366771  R1UYT6MT2IOAJN            5             23           24    N
# 4366844  R3QRYRJWX0N6H3            4             29           33    N
# 4366886   R20WGBU79NREU            5             14           20    N
#
#         verified_purchase
# 218                     Y
# 557                     Y
# 560                     N
# 909                     Y
# 1232                    Y
# ...                   ...
# 4366751                 N
# 4366765                 N
# 4366771                 N
# 4366844                 N
# 4366886                 N
#
# [26987 rows x 6 columns]

# %%
paid_5star_reviews = paid_reviews_df.loc[paid_reviews_df["star_rating"] == 5]["star_rating"].count()
paid_5star_reviews
# Out:
# 13

# %%
paid_reviews = paid_reviews_df["star_rating"].count()
paid_reviews
# Out:
# 22

# %%
percentage_5star_reviews_paid = round((paid_5star_reviews / paid_reviews) * 100, 2)
percentage_5star_reviews_paid
# Out:
# 59.09

# %%
unpaid_5star_reviews = unpaid_reviews_df.loc[unpaid_reviews_df["star_rating"] == 5]["star_rating"].count()
unpaid_5star_reviews
# Out:
# 14475

# %%
unpaid_reviews = unpaid_reviews_df["star_rating"].count()
unpaid_reviews
# Out:
# 26987

# %%
percentage_5star_reviews_unpaid = round((unpaid_5star_reviews / unpaid_reviews) * 100, 2)
percentage_5star_reviews_unpaid
# Out:
# 53.64
